# %% [markdown]
# ## Ejercicio 1

# %%
def analiza_texto(cadena):
    def dicc(**diccionario):
        for clave, valor in cadena.items():
            print(f"{clave} : {valor}")
            diccionario = {"letras": {letras}, "digitos": {digit}, "mayusculas": {mayus}, "minusculas": {minus}}
            print(diccionario)
    letras = {}
    for letra in cadena:
        letras
        letras[ord(letra)] += cadena.lower().count(letra)
    mayus = {}
    minus = {}
    digit = {}
    for letra in cadena:
        if ord(letra) in range(65,91):
            mayus[ord(letra)] +=cadena.count(ord(letra))
        if ord(letra) in range(97,123):
            minus[ord(letra)] += cadena.count(ord(letra))
        if ord(letra) in range(48,58):
            digit[ord(letra)] += cadena.count(ord(letra))
        break
    return diccionario

print(analiza_texto("Ingresa una cadena de texto"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 24
#      21         break
#      22     return diccionario
# ---> 24 print(analiza_texto("Ingresa una cadena de texto"))
#
# Cell In[4], line 10, in analiza_texto(cadena)
#       8 for letra in cadena:
#       9     letras
# ---> 10     letras[ord(letra)] += cadena.lower().count(letra)
#      11 mayus = {}
#      12 minus = {}
#
# KeyError: 73

# %%
diccionario = {"letras": {}, "digitos": {}, "mayusculas": {}, "minusculas": {}}
print(diccionario)
# Out:
# {'letras': {}, 'digitos': {}, 'mayusculas': {}, 'minusculas': {}}

# %%
def analiza_texto(cadena):
    diccionario = {"letras": {letras}, "digitos": {digit}, "mayusculas": {mayus}, "minusculas": {minus}}
    for letras in cadena:
        diccionario[letras] = 0
    for letras in diccionario.keys():
        letras += cadena.lower().count(letra)
    mayus = {}
    minus = []
    digit = []
    for letra in cadena:
        if ord(letra) in range(65,91):
            mayus +=cadena.count(ord(letra))
        if ord(letra) in range(97,123):
            minus += cadena.count(ord(letra))
        if ord(letra) in range(48,58):
            digit += cadena.count(ord(letra))
        break 
    return diccionario

# %%
print(analiza_texto("Ingresa una cadena de texto"))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(analiza_texto("Ingresa una cadena de texto"))
#
# Cell In[6], line 2, in analiza_texto(cadena)
#       1 def analiza_texto(cadena):
# ----> 2     diccionario = {"letras": {letras}, "digitos": {digit}, "mayusculas": {mayus}, "minusculas": {minus}}
#       3     for letras in cadena:
#       4         diccionario[letras] = 0
#
# UnboundLocalError: cannot access local variable 'letras' where it is not associated with a value

# %%
def dicc(**diccionario):
    for clave, valor in cadena.items():
        print(f"{clave} : {valor}")
diccionario = {"letras": {letras}, "digitos": {digit}, "mayusculas": {mayus}, "minusculas": {minus}}
print(diccionario)
